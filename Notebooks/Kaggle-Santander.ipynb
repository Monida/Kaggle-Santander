# %% [markdown]
# ## Import the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import scatter_matrix
import seaborn as sns

# %% [markdown]
# ## Import the datasets

# %%
train_set = pd.read_csv('../Data/train.csv')
test_set = pd.read_csv('../Data/test.csv')

# %% [markdown]
# ## Identify x and y for the train and test sets

# %%
x_train=train_set.iloc[:,2:202]
y_train=train_set.iloc[:,1]

x_test=test_set.iloc[:,1:201]

# %% [markdown]
# ## Create a correlation matrix to find correlation between any variable

# %%
corr_matrix = x_train.corr()

# %%
corr_matrix.head(5)
# Out:
#           var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# var_0  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046  0.006983
# var_1 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902  0.003258
# var_2  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569  0.000883
# var_3  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253 -0.000774
# var_4  0.001326  0.000303  0.000723 -0.000322  1.000000 -0.001368  0.000049
#
#           var_7     var_8     var_9  ...   var_190   var_191   var_192  \
# var_0  0.002429  0.004962 -0.002613  ...  0.002752  0.000206 -0.005373
# var_1  0.001511  0.004098 -0.000832  ...  0.006627  0.003621 -0.002604
# var_2 -0.000991  0.002648 -0.001932  ...  0.000197  0.001285 -0.003400
# var_3  0.002500  0.003553 -0.000826  ...  0.000151  0.002445 -0.001530
# var_4  0.004549  0.001194 -0.000918  ...  0.001514  0.004357  0.003347
#
#         var_193   var_194   var_195   var_196   var_197   var_198   var_199
# ...

# %% [markdown]
# ## Plot the correlation coefficient heatmap without  normalizing the variables

# %%
plt.figure(figsize=(30,30))
sns.set(font_scale=2)
sns.heatmap(corr_matrix,xticklabels=10,yticklabels=10, vmin=-0.01, vmax = 0.01)
plt.savefig('..\Figures\Corr_coeff_heatmap_nonorm.png')

# %% [markdown]
# ## Plot the correlation coefficient heatmap normalizing the variables

# %%
#x_train normalized by column
x_train_norm_col = (x_train-x_train.mean())/x_train.std()
corr_matrix_norm_col = x_train_norm_col.corr()

# %%
corr_matrix_norm_col.head()
# Out:
#           var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# var_0  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046  0.006983
# var_1 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902  0.003258
# var_2  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569  0.000883
# var_3  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253 -0.000774
# var_4  0.001326  0.000303  0.000723 -0.000322  1.000000 -0.001368  0.000049
#
#           var_7     var_8     var_9  ...   var_190   var_191   var_192  \
# var_0  0.002429  0.004962 -0.002613  ...  0.002752  0.000206 -0.005373
# var_1  0.001511  0.004098 -0.000832  ...  0.006627  0.003621 -0.002604
# var_2 -0.000991  0.002648 -0.001932  ...  0.000197  0.001285 -0.003400
# var_3  0.002500  0.003553 -0.000826  ...  0.000151  0.002445 -0.001530
# var_4  0.004549  0.001194 -0.000918  ...  0.001514  0.004357  0.003347
#
#         var_193   var_194   var_195   var_196   var_197   var_198   var_199
# ...

# %%
plt.figure(figsize=(30,30))
sns.set(font_scale=2)
sns.heatmap(corr_matrix_norm_col,xticklabels=10,yticklabels=10, vmin=-0.01, vmax = 0.01)
plt.savefig('..\Figures\Corr_coeff_heatmap_norm.png')
